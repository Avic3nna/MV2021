# %%
import cv2

cv2.namedWindow("tripod cam")
vc = cv2.VideoCapture(1)

if vc.isOpened(): # try to get the first frame
    rval, frame = vc.read()
else:
    rval = False

while rval:
    cv2.imshow("tripod cam", frame)
    rval, frame = vc.read()
    key = cv2.waitKey(20)
    if key == 27: # exit on ESC
        break

cv2.imwrite('frame1_wire.png', frame)
vc.release()
cv2.destroyWindow("tripod cam")

# %%
#this code has been tuned for frame2_wire.png (especially the boundaries which define the colour)

import cv2
import numpy as np

img = cv2.imread(r"G:\\My Drive\\1. EIT Digital master\\Estland\\Semester 1\\Machine vision\\Lab\\frame2_wire.png",1)

cv2.imshow('wire frame', img)
cv2.waitKey()

# define the list of boundaries
#we need red white and black
#https://www.etutorialspoint.com/index.php/329-detect-specific-color-from-image-using-python-opencv
boundaries = [#BGR
	([0, 20, 100], [5, 40, 150]), #red
	([160, 160, 160], [222, 222, 222]), #white
	([0, 0, 0], [15, 15, 15]) #black
]

i = 1
# loop over the boundaries
for (lower, upper) in boundaries:
	# create NumPy arrays from the boundaries
	lower = np.array(lower, dtype = "uint8")
	upper = np.array(upper, dtype = "uint8")
	# find the colors within the specified boundaries and apply
	# the mask
	mask = cv2.inRange(img, lower, upper)

	if(i == 3):
		img = cv2.bitwise_not(img)
		output = cv2.bitwise_and(img, img, mask = mask)
		#output = cv2.bitwise_not(output)
		#output = cv2.bitwise_not(output)
	else:
		output = cv2.bitwise_and(img, img, mask = mask)
	# show the images
	cv2.imshow("images", np.hstack([img, output]))
	cv2.waitKey(0)
	i += 1

# %%
import cv2
import numpy as np

img = cv2.imread(r"G:\\My Drive\\1. EIT Digital master\\Estland\\Semester 1\\Machine vision\\Lab\\frame1_wire.png",1)

cv2.imshow('wire frame', img)
cv2.waitKey()

# define the list of boundaries
#we need red white and black
#https://www.etutorialspoint.com/index.php/329-detect-specific-color-from-image-using-python-opencv
boundaries = [ #BGR
	([0, 25, 240], [10, 60, 255]), #red
	([50, 150, 230], [140, 220, 255]), #white
	([0, 0, 0], [25, 25, 25]) #black
]

i = 1
# loop over the boundaries
for (lower, upper) in boundaries:
	# create NumPy arrays from the boundaries
	lower = np.array(lower, dtype = "uint8")
	upper = np.array(upper, dtype = "uint8")
	# find the colors within the specified boundaries and apply
	# the mask
	mask = cv2.inRange(img, lower, upper)

	if(i == 3):
		img = cv2.bitwise_not(img)
		output = cv2.bitwise_and(img, img, mask = mask)
		#output = cv2.bitwise_not(output)
		#output = cv2.bitwise_not(output)
	else:
		output = cv2.bitwise_and(img, img, mask = mask)
	# show the images
	cv2.imshow("images", np.hstack([img, output]))
	cv2.waitKey(0)
	i += 1
